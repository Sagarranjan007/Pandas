# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagarranjan007/Pandas/blob/master/1_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What is pandas-python? Introduction and Installation

# %% [markdown]
# Pandas is python module that makes data science easy and effective

# %% [markdown]
# Weather dataset

# %% [markdown]
# Questions?
#
# 1. What was the maximum temparature in new york in the month of january?
#
# 2. On which days did it rains?
#
# 3. What was the average speed of wind during the month?

# %% [markdown]
# First we will see in python code

# %%
# now we will see in pandas 
import pandas as pd
df = pd.read_csv("nyc_weather.csv")
df
# Out:
#           EST  Temperature  DewPoint  ...  CloudCover    Events  WindDirDegrees
# 0    1/1/2016           38        23  ...           5       NaN             281
# 1    1/2/2016           36        18  ...           3       NaN             275
# 2    1/3/2016           40        21  ...           1       NaN             277
# 3    1/4/2016           25         9  ...           3       NaN             345
# 4    1/5/2016           20        -3  ...           0       NaN             333
# 5    1/6/2016           33         4  ...           0       NaN             259
# 6    1/7/2016           39        11  ...           3       NaN             293
# 7    1/8/2016           39        29  ...           8       NaN              79
# 8    1/9/2016           44        38  ...           8      Rain              76
# 9   1/10/2016           50        46  ...           7      Rain             109
# 10  1/11/2016           33         8  ...           1       NaN             289
# ...

# %%
from google.colab import drive
drive.mount('https://drive.google.com/file/d/1KxwFsL6IF7OD_XN28kjxl0-amnELIhZ8/view?usp=sharing')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-f83e04cff7df> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('https://drive.google.com/file/d/1KxwFsL6IF7OD_XN28kjxl0-amnELIhZ8/view?usp=sharing')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount)
#     128       # Prompt appearing here means something went wrong with the drive binary.
#     129       d.terminate(force=True)
# --> 130       raise ValueError('mount failed')
#     131     elif case == 2:
#     132       # Not already authorized, so do the authorization dance.
#
# ValueError: mount failed

# %%
#get the maximum temparature 
df['Temperature'].max()
# Out:
# 50

# %%
#to know which day it rains
df['EST'][df['Events'] == 'Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
#3. average wind speed
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %% [markdown]
# # Installation

# %% [markdown]
# pip3 install pandas
